# %%
import pandas as pd
# %matplotlib inline

# %%
myExploratoryData = pd.read_csv('C:/Users/maity/OneDrive/Desktop/New folder (19)/world-happiness-report.csv')

# %%
myExploratoryData
# Out:
#           Country  year  Lifetime    gdp  Social support  \
# 0     Afghanistan  2008     3.724  7.370           0.451
# 1     Afghanistan  2009     4.402  7.540           0.552
# 2     Afghanistan  2010     4.758  7.647           0.539
# 3     Afghanistan  2011     3.832  7.620           0.521
# 4     Afghanistan  2012     3.783  7.705           0.521
# ...           ...   ...       ...    ...             ...
# 1944     Zimbabwe  2016     3.735  7.984           0.768
# 1945     Zimbabwe  2017     3.638  8.016           0.754
# 1946     Zimbabwe  2018     3.616  8.049           0.775
# 1947     Zimbabwe  2019     2.694  7.950           0.759
# 1948     Zimbabwe  2020     3.160  7.829           0.717
#
#       Healthy life expectancy at birth  Freedom   Generosity  \
# 0                                50.80     0.718       0.168
# 1                                51.20     0.679       0.190
# 2                                51.60     0.600       0.121
# ...

# %%
import seaborn as sns

# %%
sns.kdeplot(myExploratoryData.year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.kdeplot(myExploratoryData.gdp)
# Out:
# <AxesSubplot:xlabel='gdp', ylabel='Density'>

# %%
sns.kdeplot(myExploratoryData.Generosity)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(myExploratoryData.year)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(myExploratoryData.Generosity)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(myExploratoryData.gdp)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp', ylabel='Density'>

# %%
myExploratoryData.plot(kind='scatter',x='year',y='gdp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='gdp'>

# %%
myExploratoryData.plot(kind='scatter',x='year',y='Country')
# Out:
# <AxesSubplot:xlabel='year', ylabel='Country'>

# %%
from scipy import stats

# %%
slope, intercept,r_value, p_value, std_err = stats.linregress(myExploratoryData.gdp,myExploratoryData.year)

# %%
print("R-Squared Value:" ,r_value**2)
# Out:
# R-Squared Value: nan
